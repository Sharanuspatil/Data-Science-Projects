# %%
def modelpipeline(imagepath,model,label=-1):
    pdict = {0:"jute",1:"maize",2:"rice",3:"sugarcane",4:"wheat"}
    img = plt.imread(imagepath)
    img = img/255.
    img.reshape([1,-1])
    flat =  np.array(img)
    flat = flat.reshape(-1,224*224*3)       
    pred = model.predict(flat)
    plt.imshow(plt.imread(imagepath))
    if (label!=-1):
        plt.title("prediction : {} \naccurate  : {}".format(pdict[pred[0]],pdict[label]))
    else:
        plt.title("prediction : {}".format(pdict[pred[0]]))

# %%
import pickle
import matplotlib as plt
import matplotlib.pyplot as plt

model=pickle.load(open('lr_model.pkl','rb'))
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\base.py:334: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.23.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
modelpipeline('C:\\Users\\Dell\\New folder (7)\\kag2\\jute\\jute004arot.jpeg',model)
